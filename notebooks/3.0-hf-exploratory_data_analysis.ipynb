# %% [markdown]
# # Checklist
# - Data Info
# - Data Describe
# - Missing Values
# - Duplicated Values
# - Unique Values
# - Outliers
# - Distributions
# - Correlations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from src.utils.visualize import Visualize

# %%
data = pd.read_csv('../data/interim/data.csv')

# %%
data.head()
# Out:
#                                                title       location  master  \
# 0       Schaefer Halleen’S Social Equity Scholarship  United States       1
# 1                President’S Scholarship For Ukraine  United States       1
# 2  International Students Diversity Contest 2022 ...  United States       1
# 3  Master In Business Administration 80% Off Your...  United States       1
# 4                   Improve Men’S Health Scholarship  United States       1
#
#    bachelor  phd  course
# 0         1    1       0
# 1         1    1       1
# 2         1    1       1
# 3         0    0       0
# 4         1    1       0

# %% [markdown]
# # Data Info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877 entries, 0 to 876
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     877 non-null    object
#  1   location  877 non-null    object
#  2   master    877 non-null    int64
#  3   bachelor  877 non-null    int64
#  4   phd       877 non-null    int64
#  5   course    877 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 41.2+ KB

# %% [markdown]
# # Data Describe

# %%
data.describe()
# Out:
#            master    bachelor         phd      course
# count  877.000000  877.000000  877.000000  877.000000
# mean     0.525656    0.478905    0.329532    0.240593
# std      0.499626    0.499840    0.470312    0.427687
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000

# %% [markdown]
# # Missing Values

# %%
data.isnull().sum()
# Out:
# title       0
# location    0
# master      0
# bachelor    0
# phd         0
# course      0
# dtype: int64

# %% [markdown]
# # Duplicated Values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Unique Values

# %%
for feature in data.columns:
    print(feature, ':', len(data[feature].unique()))
# Out:
# title : 471
# location : 8
# master : 2
# bachelor : 2
# phd : 2
# course : 2

# %% [markdown]
# # Outliers
# There aren't any numerical columns.

# %%
visualize = Visualize()
for feature in ['location']:
    visualize.plot_counts(data[feature], ascending=True, max_items=10)

# %% [markdown]
# # Distributions

# %%
for feature in ['location', 'master', 'bachelor', 'phd', 'course']:
    visualize.plot_counts(data[feature], ascending=False, max_items=10)

# %% [markdown]
# # Correlations

# %%
correlations = data[['master', 'bachelor', 'phd', 'course']].corr()

# %%
sns.heatmap(correlations, cmap='Blues', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Conclusion
# - Nothing noteworthy
